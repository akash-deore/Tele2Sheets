# %%
# ---------- Cell 1/3 ----------
# Run this first in Colab

# Install required packages
# !pip install python-telegram-bot==21.4 gspread nest_asyncio --upgrade --quiet

# Authenticate Google user for Colab access to Sheets
from google.colab import auth
auth.authenticate_user()

# Get Bot token from Colab userdata (set this in Colab's "Manage Sessions" or similar)
from google.colab import userdata
BotFather_API_Key = userdata.get('BotFather_API_Key')  # set this value in Colab
if not BotFather_API_Key:
    raise RuntimeError("Bot token not found in userdata['BotFather_API_Key']. Set it before running.")

print("✔ Packages installed and Colab authenticated.")
